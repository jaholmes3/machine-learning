# %% [markdown]
# # Strategy Learner
#
#
# ---
#
# This notebook provides an example of how a StrategyLearner works. This code is also available in the `__main__` function of `StrategyLearner.py`.

# %% [markdown]
# ## Summary
#
# We choose a stock, an in-sample period and an out-of-sample period. We train a StrategyLearner on the data from the in-sample period and test it on the out-of-sample period. Then we report the performances of the portfolio (only consisting of the stock) and benchmark for both periods. Benchmark is The performance of a portfolio starting with ``$``100,000 cash, investing in 1000 shares of JPM and holding that position.
#
# * In this notebook, we choose the CME S&P 500 Emini futures contract (March Contracts ESH2009 and ESH2010)
# * The in sample/development period is January 1, 2008 to December 31 2009.
# * The out of sample/testing period is January 1, 2010 to December 31 2011.
# * Starting cash is ``$``100,000.
# * Allowable positions are: 5 contracts Long, 5 contracts short, 0 shares.
# * There is no limit on leverage.
# * Transaction costs: Commission: $0.00, Impact: 0.0.
#
# __*The performance of portfolio is better than benchmark in both periods!*__

# %% [markdown]
# ## Table of contents:
# [1) In-sample performance](#first)
#
# [2) Out-of-sample performance](#second)
#
# [3) Out-of-sample performance](#third)

# %% [markdown]
# Import relevant libraries and modules

# %%
import datetime as dt
import pandas as pd


from util import create_df_benchmark
from StrategyLearner import StrategyLearner
from marketsim import compute_portvals_single_symbol, market_simulator
from pandas.plotting import register_matplotlib_converters

from indicators import plot_bollinger, get_bollinger_bands, compute_bollinger_value

# %% [markdown]
# Starting cash, symbol of interest, commission, and impact
#
#
#
# |Month     | contract| date range              |
# |----------|---------|-------------------------|
# |March     | ESH2009 | 2009-03-19 to 2007-12-21|
# |June      | ESM2009 | 2009-06-18 to 2008-03-20|
# |September | ESU2009 | 2009-09-17 to 2008-06-20|
# |December  | ESZ2009 | 2009-12-17 to 2008-09-19|

# %%
from indicators import plot_bollinger, get_bollinger_bands, compute_bollinger_value
from util import get_exchange_days, get_data, normalize_data
import matplotlib.pyplot as plt

# %%
start_val = 100000
symbol = "ESFULL"
commission = 0.00
impact = 0.0
num_shares = 5

# %% [markdown]
# ---
# ## 1) In-sample performance <a class="anchor" id="first"></a>
#
# Show the performances of portfolio and benchmark in the in-sample period

# %% [markdown]
# Specify the start and end dates for this period

# %%
start_date = dt.datetime(2014, 10, 6)
end_date = dt.datetime(2018, 4, 3)

# %% [markdown]
# Get a dataframe of benchmark data. Benchmark is a portfolio starting with ``$``100,000, investing in 1000 shares of symbol and holding that position

# %%
df_price = get_data(symbols, dates)
    norm_price = normalize_data(df_price)
    window = 20
    num_std = 2

# Plot Bollinger bands and values
plot_bollinger(norm_price[symbol], upper_band, lower_band, 
        bollinger_val, num_std, 
        "Bollinger Indicator for {} with num_std={}, lookback={} days \
        \n(Prices are normalized to the first date)".
        format(symbol, num_std, window))
# Out:
#   File "<ipython-input-32-ed77352366e5>", line 2
#     norm_price = normalize_data(df_price)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# Create an instance of StrategyLearner and retrieve a trades dataframe via test_policy

# %%
# Train and test a StrategyLearner
# Set verbose to True will print out and plot the cumulative return for each training epoch
stl = StrategyLearner(num_shares=num_shares, impact=impact, 
                      commission=commission, verbose=True,
                      num_states=3000, num_actions=3)
stl.add_evidence(symbol=symbol, start_val=start_val, 
                 start_date=start_date, end_date=end_date)
df_trades = stl.test_policy(symbol=symbol, start_date=start_date,
                            end_date=end_date)
print (df_trades)
# Out:
# 1 -0.017325000000000035
# 2 0.004574999999999996
# 3 0.01693750000000005
# 4 0.016712499999999908
# 5 0.016712499999999908
# 6 0.016712499999999908
# 7 0.016712499999999908
# 8 0.016712499999999908
# 9 0.016712499999999908
# 10 0.016712499999999908
# 11 0.016712499999999908
# 12 0.016712499999999908
# 13 0.016712499999999908
# 14 0.016712499999999908
# 15 0.016712499999999908
# 16 0.016712499999999908
# 17 0.016712499999999908
# 18 0.016712499999999908
# 19 0.016712499999999908
# 20 0.016712499999999908
# 21 0.016712499999999908
#             Shares
# Date
# 2014-11-21       5
# 2014-11-28      -5
# 2014-12-10      -5
# 2014-12-18       5
# 2014-12-30      -5
# 2015-01-13       5
# 2015-01-14      -5
# 2015-01-15       5
# 2015-01-16      -5
# 2015-02-03       5
# 2015-02-06      -5
# 2015-02-09       5
# 2015-03-10      -5
# 2015-03-18       5
# 2015-03-19      -5
# 2015-04-08       5
# 2015-04-16      -5
# 2015-04-17       5
# 2015-04-20      -5
# 2015-04-21       5
# 2015-05-04       5
# 2015-05-05      -5
# 2015-05-22      -5
# 2015-05-26       5
# 2015-06-08      -5
# 2015-06-10       5
# 2015-06-12      -5
# 2015-06-23       5
# 2015-06-24      -5
# 2015-07-14       5
# ...            ...
# 2016-05-11      -5
# 2016-05-26       5
# 2016-06-24      -5
# 2016-07-08       5
# 2016-09-09      -5
# 2016-10-07       5
# 2016-10-10      -5
# 2016-10-11       5
# 2016-10-13      -5
# 2016-10-24       5
# 2016-10-25      -5
# 2016-11-08       5
# 2017-03-02       5
# 2017-03-03      -5
# 2017-03-21      -5
# 2017-04-19       5
# 2017-06-29      -5
# 2017-07-12       5
# 2017-08-11      -5
# 2017-08-16       5
# 2017-08-17      -5
# 2017-09-06       5
# 2017-09-07      -5
# 2017-09-08       5
# 2017-09-28       5
# 2017-09-29      -5
# 2018-02-02      -5
# 2018-03-06       5
# 2018-03-16      -5
# 2018-04-03       5
#
# [80 rows x 1 columns]

# %% [markdown]
# Retrieve performance stats via a market simulator

# %%
# Retrieve performance stats via a market simulator
print ("Performances during training period for {}".format(symbol))
print ("Date Range: {} to {}".format(start_date, end_date))
market_simulator(df_trades, df_benchmark_trades, symbol=symbol, 
                 start_val=start_val, commission=commission, impact=impact)
# Out:
# Performances during training period for ESFULL
# Date Range: 2014-10-06 00:00:00 to 2018-04-03 00:00:00
# Sharpe Ratio of Portfolio: 0.4197049159501236
# Sharpe Ratio of Benchmark : 0.6518987130617278
#
# Cumulative Return of Portfolio: 0.016712499999999908
# Cumulative Return of Benchmark : 0.03286250000000002
#
# Standard Deviation of Portfolio: 0.000753488025533817
# Standard Deviation of Benchmark : 0.0009068029224496715
#
# Average Daily Return of Portfolio: 1.9921413066020324e-05
# Average Daily Return of Benchmark : 3.7238550203955216e-05
#
# Final Portfolio Value: 101671.25
# Final Benchmark Value: 103286.25

# %% [markdown]
# ---
# ## 2) Out-of-sample performance <a class="anchor" id="second"></a>
#
# Show the performances of portfolio and benchmark in the out-of-sample period

# %% [markdown]
# Specify the start and end dates for this period

# %%
start_val = 100000
symbol = "ESFULL"
commission = 0.00
impact = 0.0
num_shares = 5

# %%
start_date = dt.datetime(2014, 10, 6)
end_date = dt.datetime(2018, 4, 3)

# %% [markdown]
# Get a dataframe of benchmark data. Benchmark is a portfolio starting with ``$``100,000, investing in 1000 shares of symbol and holding that position.

# %%
df_benchmark_trades = create_df_benchmark(symbol, start_date, end_date, 
                                          num_shares)
print (df_benchmark_trades)
# Out:
#             Shares
# Date
# 2014-10-06       5
# 2018-04-03      -5

# %% [markdown]
# Use the same StrategyLearner trained above and retrieve a trades dataframe via test_policy

# %%
df_trades = stl.test_policy(symbol=symbol, start_date=start_date, 
                            end_date=end_date)
print (df_trades)
# Out:
#             Shares
# Date
# 2014-11-21       5
# 2014-11-28      -5
# 2014-12-10      -5
# 2014-12-18       5
# 2014-12-30      -5
# 2015-01-13       5
# 2015-01-14      -5
# 2015-01-15       5
# 2015-01-16      -5
# 2015-02-03       5
# 2015-02-06      -5
# 2015-02-09       5
# 2015-03-10      -5
# 2015-03-18       5
# 2015-03-19      -5
# 2015-04-08       5
# 2015-04-16      -5
# 2015-04-17       5
# 2015-04-20      -5
# 2015-04-21       5
# 2015-05-04       5
# 2015-05-05      -5
# 2015-05-22      -5
# 2015-05-26       5
# 2015-06-08      -5
# 2015-06-10       5
# 2015-06-12      -5
# 2015-06-23       5
# 2015-06-24      -5
# 2015-07-14       5
# ...            ...
# 2016-05-11      -5
# 2016-05-26       5
# 2016-06-24      -5
# 2016-07-08       5
# 2016-09-09      -5
# 2016-10-07       5
# 2016-10-10      -5
# 2016-10-11       5
# 2016-10-13      -5
# 2016-10-24       5
# 2016-10-25      -5
# 2016-11-08       5
# 2017-03-02       5
# 2017-03-03      -5
# 2017-03-21      -5
# 2017-04-19       5
# 2017-06-29      -5
# 2017-07-12       5
# 2017-08-11      -5
# 2017-08-16       5
# 2017-08-17      -5
# 2017-09-06       5
# 2017-09-07      -5
# 2017-09-08       5
# 2017-09-28       5
# 2017-09-29      -5
# 2018-02-02      -5
# 2018-03-06       5
# 2018-03-16      -5
# 2018-04-03       5
#
# [80 rows x 1 columns]

# %% [markdown]
# Retrieve performance stats via a market simulator

# %%
print ("\nPerformances during testing period for {}".format(symbol))
print ("Date Range: {} to {}".format(start_date, end_date))
market_simulator(df_trades, df_benchmark_trades, symbol=symbol, 
                 start_val=start_val, commission=commission, impact=impact)
# Out:
# Performances during testing period for ESFULL
# Date Range: 2014-10-06 00:00:00 to 2018-04-03 00:00:00
# Sharpe Ratio of Portfolio: 0.4197049159501236
# Sharpe Ratio of Benchmark : 0.6518987130617278
#
# Cumulative Return of Portfolio: 0.016712499999999908
# Cumulative Return of Benchmark : 0.03286250000000002
#
# Standard Deviation of Portfolio: 0.000753488025533817
# Standard Deviation of Benchmark : 0.0009068029224496715
#
# Average Daily Return of Portfolio: 1.9921413066020324e-05
# Average Daily Return of Benchmark : 3.7238550203955216e-05
#
# Final Portfolio Value: 101671.25
# Final Benchmark Value: 103286.25

# %% [markdown]
# ---
# ## 3) Out-of-sample performance <a class="anchor" id="third"></a>
#
# Show the performances of portfolio and benchmark in the out-of-sample period

# %% [markdown]
# Specify the start and end dates for this period
# J7H2009
# start_date = dt.datetime(2008, 3, 18)
# end_date = dt.datetime(2009, 3, 16)

# %%
start_val = 100000
symbol = "SINE_FAST"
commission = 0.00
impact = 0.0
num_shares = 5

# %%
start_date = dt.datetime(2008, 12, 19)
end_date = dt.datetime(2010, 3, 19)

# %% [markdown]
# Get a dataframe of benchmark data. Benchmark is a portfolio starting with ``$``100,000, investing in 1000 shares of symbol and holding that position.

# %%
df_benchmark_trades = create_df_benchmark(symbol, start_date, end_date, 
                                          num_shares)
print (df_benchmark_trades)
# Out:
#             Shares
# Date
# 2008-12-19       5
# 2010-03-19      -5

# %% [markdown]
# Use the same StrategyLearner trained above and retrieve a trades dataframe via test_policy

# %%
df_trades = stl.test_policy(symbol=symbol, start_date=start_date, 
                            end_date=end_date)
print (df_trades)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-cf8cb7b67955> in <module>()
#       1 df_trades = stl.test_policy(symbol=symbol, start_date=start_date,
# ----> 2                             end_date=end_date)
#       3 print (df_trades)
#
# ~/Envs/machine-learning/projects/capstone/StrategyLearner.py in test_policy(self, symbol, start_date, end_date, start_val)
#     254         # Get features and thresholds
#     255         df_features = self.get_features(df_prices[symbol])
# --> 256         thresholds = self.get_thresholds(df_features, self.num_steps)
#     257         # Initial position is holding nothing
#     258         position = self.CASH
#
# ~/Envs/machine-learning/projects/capstone/StrategyLearner.py in get_thresholds(self, df_features, num_steps)
#      86             for step in range(num_steps):
#      87                 if step < num_steps - 1:
# ---> 88                     thres[i, step] = df_copy[feat].iloc[(step + 1) * step_size]
#      89                 # The last threshold must be = the largest value in df_copy
#      90                 else:
#
# ~/Envs/sklearn_py3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/Envs/sklearn_py3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2100
#    2101             # validate the location
# -> 2102             self._validate_integer(key, axis)
#    2103
#    2104             return self._get_loc(key, axis=axis)
#
# ~/Envs/sklearn_py3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2007         l = len(ax)
#    2008         if key >= l or key < -l:
# -> 2009             raise IndexError("single positional indexer is out-of-bounds")
#    2010
#    2011     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# Retrieve performance stats via a market simulator

# %%
print ("\nPerformances during testing period for {}".format(symbol))
print ("Date Range: {} to {}".format(start_date, end_date))
market_simulator(df_trades, df_benchmark_trades, symbol=symbol, 
                 start_val=start_val, commission=commission, impact=impact)
